# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('IMDb_movies.csv')

# %%
data.head(10)
# Out:
#   imdb_title_id                                              title  \
# 0     tt0000574                        The Story of the Kelly Gang
# 1     tt0001892                                     Den sorte drøm
# 2     tt0002101                                          Cleopatra
# 3     tt0002130                                          L'Inferno
# 4     tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# 5     tt0002423                                     Madame DuBarry
# 6     tt0002445                                         Quo Vadis?
# 7     tt0002452                              Independenta Romaniei
# 8     tt0002461                                        Richard III
# 9     tt0002646                                           Atlantis
#
#                                       original_title  year date_published  \
# 0                        The Story of the Kelly Gang  1906     1906-12-26
# 1                                     Den sorte drøm  1911     1911-08-19
# ...

# %%
data.shape
# Out:
# (81273, 22)

# %%
data.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
data['year'].value_counts().sort_index()
# Out:
# 1906       1
# 1911       4
# 1912       5
# 1913      13
# 1914      21
#         ...
# 2015    2903
# 2016    3033
# 2017    3106
# 2018    2880
# 2019    1567
# Name: year, Length: 110, dtype: int64

# %%
(data.title == 'The Imitation Game').sum()
# Out:
# 1

# %%
data['title'][2]
# Out:
# 'Cleopatra'

# %%
data.dropna(axis=0, how='any',inplace=True)

# %%
data['comb'] = data['actors'] + ' '+ data['director'] +' ' + data['genre']

# %%
data["comb"] = data["comb"].str.replace(","," ")

# %%
data
# Out:
#       imdb_title_id                            title  \
# 488       tt0017136                       Metropolis
# 1005      tt0021749                      City Lights
# 2336      tt0027977                     Modern Times
# 2687      tt0029583  Snow White and the Seven Dwarfs
# 3100      tt0031381               Gone with the Wind
# ...             ...                              ...
# 80665     tt8772262                        Midsommar
# 80858     tt9024106                        Unplanned
# 80908     tt9082020                Cold Blood Legacy
# 80946     tt9134216                Playing with Fire
# 81059     tt9354944                             Jexi
#
#                         original_title  year date_published  \
# 488                         Metropolis  1927     1927-02-06
# 1005                       City Lights  1931     1931-08-21
# 2336                      Modern Times  1936     1936-10-16
# 2687   Snow White and the Seven Dwarfs  1937     1938-07-08
# ...

# %%
data.drop(['usa_gross_income','worlwide_gross_income','metascore','budget','reviews_from_users','reviews_from_critics','description','country', 'original_title','writer','year','duration','votes','production_company',],axis=1,inplace=True)

# %%
data
# Out:
#       imdb_title_id                            title date_published  \
# 488       tt0017136                       Metropolis     1927-02-06
# 1005      tt0021749                      City Lights     1931-08-21
# 2336      tt0027977                     Modern Times     1936-10-16
# 2687      tt0029583  Snow White and the Seven Dwarfs     1938-07-08
# 3100      tt0031381               Gone with the Wind     1942-09-04
# ...             ...                              ...            ...
# 80665     tt8772262                        Midsommar     2019-07-03
# 80858     tt9024106                        Unplanned     2019-10-04
# 80908     tt9082020                Cold Blood Legacy     2019-05-15
# 80946     tt9134216                Playing with Fire     2019-11-08
# 81059     tt9354944                             Jexi     2019-10-11
#
#                             genre          language  \
# 488                 Drama, Sci-Fi            German
# ...

# %%
data.drop(['language'],axis=1, inplace=True)

# %%
data
# Out:
#       imdb_title_id                            title date_published  \
# 488       tt0017136                       Metropolis     1927-02-06
# 1005      tt0021749                      City Lights     1931-08-21
# 2336      tt0027977                     Modern Times     1936-10-16
# 2687      tt0029583  Snow White and the Seven Dwarfs     1938-07-08
# 3100      tt0031381               Gone with the Wind     1942-09-04
# ...             ...                              ...            ...
# 80665     tt8772262                        Midsommar     2019-07-03
# 80858     tt9024106                        Unplanned     2019-10-04
# 80908     tt9082020                Cold Blood Legacy     2019-05-15
# 80946     tt9134216                Playing with Fire     2019-11-08
# 81059     tt9354944                             Jexi     2019-10-11
#
#                             genre                       director  \
# 488                 Drama, Sci-Fi                     Fritz Lang
# ...

# %%
data.to_csv('data_prep1.csv', index=False)
